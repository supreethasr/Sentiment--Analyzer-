# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  Load the dataset into a Dataframe

# %%
df = pd.read_csv("/content/Emotion_final.csv")

df.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3                              I am in love with you     love
# 4  i am ever feeling nostalgic about the fireplac...     love

# %%
original_size = df.shape[0]
print(original_size)
# Out:
# 21490

# %% [markdown]
# Perform the data cleaning

# %%
df.isnull().sum()
# Out:
# Text       0
# Emotion    0
# dtype: int64

# %%
df.dtypes
# Out:
# Text       object
# Emotion    object
# dtype: object

# %%
df.describe()
# Out:
#                                                      Text Emotion
# count                                               21493   21493
# unique                                              21439       7
# top     i often find myself feeling assaulted by a mul...   happy
# freq                                                    2    7033

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21493 entries, 0 to 21492
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Text     21493 non-null  object
#  1   Emotion  21493 non-null  object
# dtypes: object(2)
# memory usage: 336.0+ KB

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates()
# Out:
#                                                     Text    Emotion
# 0                                i didnt feel humiliated    sadness
# 1      i can go from feeling so hopeless to so damned...    sadness
# 2       im grabbing a minute to post i feel greedy wrong      anger
# 3                                  I am in love with you       love
# 4      i am ever feeling nostalgic about the fireplac...       love
# ...                                                  ...        ...
# 21488                            I don't know what to do  confusion
# 21489    I have never come across this kind of situation  confusion
# 21490                             Which way should I go?  confusion
# 21491                       I barely understood anything  confusion
# 21492               I am puzzled under this circumstance  confusion
#
# [21490 rows x 2 columns]

# %%
df['Text'] = df['Text'].str.strip().str.lower()
print(df['Text'])
# Out:
# 0                                  i didnt feel humiliated
# 1        i can go from feeling so hopeless to so damned...
# 2         im grabbing a minute to post i feel greedy wrong
# 3                                    i am in love with you
# 4        i am ever feeling nostalgic about the fireplac...
#                                ...
# 21488                              i don't know what to do
# 21489      i have never come across this kind of situation
# 21490                               which way should i go?
# 21491                         i barely understood anything
# 21492                 i am puzzled under this circumstance
# Name: Text, Length: 21490, dtype: object

# %%
print(df.head())
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3                              i am in love with you     love
# 4  i am ever feeling nostalgic about the fireplac...     love

# %%
df = df.drop_duplicates(subset=['Text', 'Emotion'])
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3                              i am in love with you     love
# 4  i am ever feeling nostalgic about the fireplac...     love

# %%
cleaned_size = df.shape[0]
print("\nChecking for duplicates after removal:")
print(f"Number of duplicate rows after removal: {df.duplicated().sum()}")
print(f"Original dataset size: {original_size}")
print(f"Cleaned dataset size: {cleaned_size}")
# Out:
# Checking for duplicates after removal:
# Number of duplicate rows after removal: 0
# Original dataset size: 21490
# Cleaned dataset size: 21490

# %% [markdown]
#  Label encode the Emotion column

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Emotion'] = label_encoder.fit_transform(df['Emotion'])
print(df['Emotion'])
# Out:
# 0        5
# 1        5
# 2        0
# 3        4
# 4        4
#         ..
# 21488    1
# 21489    1
# 21490    1
# 21491    1
# 21492    1
# Name: Emotion, Length: 21490, dtype: int64

# %%
print("\nUnique labels after encoding:")
print(df['Emotion'].unique())
# Out:
# Unique labels after encoding:
# [5 0 4 6 2 3 1]

# %% [markdown]
# Train a random forest model with the dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Emotion'], test_size=0.2, random_state=42)
print("X_train:")
print(X_train)
print("\nX_test:")
print(X_test)
print("\ny_train:")
print(y_train)
print("\ny_test:")
print(y_test)
# Out:
# X_train:
# 20870    herman , startled but pleased , moved in , onl...
# 11913    i wasnt going to make this about what i cant e...
# 2101     i suppose most of my writing emerges out of so...
# 11099    i stepped outside of the house feeling glad to...
# 4197     i do have good days and bad days but the bad d...
#                                ...
# 11284      i feel so amazed ive had views in the past week
# 11964    i am tired of feeling sorry for myself so i de...
# 5390     i get close to feeling what that is like is th...
# 860      i feel impatient yet i am not fully sure what ...
# 15796    i watch iggy azealea strutting down a desert r...
# Name: Text, Length: 17192, dtype: object
#
# X_test:
# 3533     i do feel sympathetic and try to help when i c...
# 3616               i feel so shitty right now i just arugh
# 14339         i feel they look a little awkward just below
# 18219              i feel lonely and he always talks to me
# 8829                                             in sweden
#                                ...
# 9785        i feel determined to give this process a label
# 11146    i just go into these modes where i want to wri...
# 9098     i consider roethisberger stating how he feels ...
# 13445    i am filled with despair when i feel like my q...
# 6888                              i feel hateful sometimes
# Name: Text, Length: 4298, dtype: object
#
# y_train:
# 20870    6
# 11913    5
# 2101     5
# 11099    3
# 4197     5
#         ..
# 11284    6
# 11964    5
# 5390     3
# 860      0
# 15796    3
# Name: Emotion, Length: 17192, dtype: int64
#
# y_test:
# 3533     4
# 3616     5
# 14339    5
# 18219    5
# 8829     2
#         ..
# 9785     3
# 11146    0
# 9098     3
# 13445    3
# 6888     0
# Name: Emotion, Length: 4298, dtype: int64

# %%
vectorizer = TfidfVectorizer(max_features=5000)
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)
print(X_train_vect)
print(X_test_vect)
# Out:
#   (0, 2082)	0.43711363923726193
#   (0, 3437)	0.44865717416944284
#   (0, 269)	0.1821074241661191
#   (0, 380)	0.17079632303606984
#   (0, 4484)	0.09996811504429502
#   (0, 3084)	0.25245660957757954
#   (0, 2249)	0.13696176053697331
#   (0, 2909)	0.4012561446118863
#   (0, 3282)	0.33499160546738155
#   (0, 605)	0.15599684632529973
#   (0, 4111)	0.39402605951870184
#   (1, 959)	0.13640179791275817
#   (1, 1801)	0.23464657366394998
#   (1, 4655)	0.11697357860510946
#   (1, 214)	0.15899931599630474
#   (1, 1847)	0.1987126897488463
#   (1, 3100)	0.11085888332684728
#   (1, 4216)	0.20130963937163215
#   (1, 4772)	0.2736330037769771
#   (1, 2589)	0.08463798967640285
#   (1, 1622)	0.044281105372367166
#   (1, 177)	0.10899827482235663
#   (1, 1339)	0.4004871883351063
#   (1, 639)	0.15305792927666434
#   (1, 4830)	0.3675160610522936
#   :	:
#   (17191, 4198)	0.2048135148435368
#   (17191, 3660)	0.22671170628440118
#   (17191, 1068)	0.22671170628440118
#   (17191, 4782)	0.20076156312178203
#   (17191, 2209)	0.11997704692653946
#   (17191, 2064)	0.15373563957731948
#   (17191, 4435)	0.1497750378048389
#   (17191, 4401)	0.14238157827090714
#   (17191, 2071)	0.12707055329781794
#   (17191, 3711)	0.1699224576177101
#   (17191, 1270)	0.15117364304020084
#   (17191, 2887)	0.11241712924030511
#   (17191, 4931)	0.12813617871204686
#   (17191, 1726)	0.17873808467029131
#   (17191, 2646)	0.15740912186764552
#   (17191, 3790)	0.18067631067322618
#   (17191, 3117)	0.11954979315355209
#   (17191, 3059)	0.07031773650239331
#   (17191, 3100)	0.11055706409342157
#   (17191, 1622)	0.08832109539380073
#   (17191, 177)	0.05435076059750154
#   (17191, 639)	0.1526412208858013
#   (17191, 269)	0.10477957957955442
#   (17191, 2249)	0.1576080245300578
#   (17191, 605)	0.0897562746194852
#   (0, 4987)	0.25779455076945523
#   (0, 4835)	0.36044992491399713
#   (0, 4578)	0.2882509074268036
#   (0, 4484)	0.09854747378167747
#   (0, 4289)	0.3386858463870879
#   (0, 3136)	0.2744425638300924
#   (0, 2395)	0.2880118357920323
#   (0, 2064)	0.2633962280764466
#   (0, 1622)	0.07566054120654003
#   (0, 1249)	0.1964135355720791
#   (0, 1178)	0.3403858797171098
#   (0, 858)	0.36849385069928525
#   (0, 633)	0.20047402193495137
#   (0, 605)	0.15377998391242204
#   (0, 177)	0.0931194963889158
#   (1, 3985)	0.2909266528764674
#   (1, 3851)	0.6327833374593698
#   (1, 3652)	0.4684237391833563
#   (1, 3031)	0.4013035955483193
#   (1, 2458)	0.3375234265635961
#   (1, 1622)	0.1433858143964028
#   (2, 4415)	0.3039385241493202
#   (2, 2646)	0.3763700754442449
#   (2, 2619)	0.2963965779349096
#   (2, 2458)	0.2485520646436289
#   :	:
#   (4295, 3689)	0.335200485817385
#   (4295, 2165)	0.2151461833598791
#   (4295, 2023)	0.21061986518842302
#   (4295, 2018)	0.16029874983996076
#   (4295, 1804)	0.35573111334509677
#   (4295, 1626)	0.254972094355278
#   (4295, 910)	0.392563972358366
#   (4295, 380)	0.1701625601036165
#   (4295, 177)	0.09411137532566745
#   (4296, 4884)	0.15760688104545548
#   (4296, 4835)	0.17683202006483392
#   (4296, 3618)	0.3374904789645581
#   (4296, 3449)	0.44063628234416014
#   (4296, 2938)	0.1286199458354396
#   (4296, 2589)	0.14189343224521087
#   (4296, 2390)	0.34753128074805395
#   (4296, 1726)	0.15023394136454485
#   (4296, 1654)	0.3678192195089263
#   (4296, 1622)	0.07423614441835905
#   (4296, 1148)	0.3833381977538619
#   (4296, 390)	0.37694189987045307
#   (4296, 159)	0.16115189445481018
#   (4297, 4018)	0.5863607280217871
#   (4297, 2015)	0.7938995774960484
#   (4297, 1622)	0.16094892818952003

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
print(clf.fit(X_train_vect, y_train))
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
#  Find the accuracy of the model

# %%
y_pred = clf.predict(X_test_vect)
accuracy = accuracy_score(y_test, y_pred)

print(f'\nAccuracy of the Random Forest model: {accuracy * 100:.2f}%')
# Out:
# Accuracy of the Random Forest model: 85.16%
